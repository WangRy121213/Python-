# %%
import time
import os

def re_exe(cmd,inc = 10):
    while True:
        print(cmd)
        time.sleep(inc)
re_exe("fra",12)

# %%
#! /usr/bin/env python
#coding=utf-8
#这里需要引入三个模块
import time, os, sched 
    
# 第一个参数确定任务的时间，返回从某个特定的时间到现在经历的秒数 
# 第二个参数以某种人为的方式衡量时间 
schedule = sched.scheduler(time.time, time.sleep) 
    
def perform_command(cmd, inc): 
    print(cmd) 
        
def timming_exe(cmd, inc = 60): 
    # enter用来安排某事件的发生时间，从现在起第n秒开始启动 
    schedule.enter(inc, 0, perform_command, (cmd, inc)) 
    # 持续运行，直到计划时间队列变成空为止 
    schedule.run() 
        
    
print("show time after 10 seconds:") 
timming_exe("This is the i time to run", 10)

# %%
#! /usr/bin/env python
#coding=utf-8

#周期调用
import time, os, sched 
    
# 第一个参数确定任务的时间，返回从某个特定的时间到现在经历的秒数 
# 第二个参数以某种人为的方式衡量时间 
schedule = sched.scheduler(time.time, time.sleep) 

#该函数即为需要反复执行的函数
#inc为间隔周期
def perform_command(cmd, inc): 
    # 安排inc秒后再次运行自己，即周期运行 
    schedule.enter(inc, 0, perform_command, (cmd, inc)) 
    print("perform_command: ",cmd) 
        
def timming_exe(cmd, inc = 60): 
    # enter用来安排某事件的发生时间，从现在起第n秒开始启动 
    schedule.enter(inc, 0, perform_command, (cmd, inc)) 
    # 持续运行，直到计划时间队列变成空为止 
    schedule.run() 
        
    
print("show time after 10 seconds:") 
timming_exe("This is the 0 time to run", 10)

# %% [markdown]
# # MySQL
#
#    基本知识：
#
#         enum(枚举类型):限定数据可选择的内容
#
#         char(10)和varchar的主要区别：
#
#               1. char长度固定，varchar长度不固定
#
#               2. char效率比varchar的效率高
#
#               3. char会截掉输入数据长出其设定数据长度的部分
#                  varchar储存长度则为实际数据的长度
#
#    cmd窗口登陆数据库：
#
#         mysql -u root -p
#
#    创建，指定数据库存放数据：
#
#        >CREATE DATABASE scraping   >USE scraping
#
#    创建表
#
#        >CREATE TABLE pages(id BIGINT(7) NOT NULL AUTO_INCREMENT, title     VARCHAR(200),content VARCHAR(10000), created TIMESTAMP DEFAULT CURRENT_TIMESTAMP, PRIMARY KEY(id))
#
#    插入字段
#
#        >INSERT INTO pages(title,content) VALUES ("Test page title", "This is some test page content. It can be up to 10,000 characters long.");
#
#    数据选择和查询语句
#
#        > SELECT * From pages WHERE id=2;
#
#        > SELECT * FROM pages WHERE title LIKE "%test%"(title包含test的所有行)
#
#        > SELECT id, title FROM pages WHERE content LIKE "%page content%"
#
#    数据删除与更新
#
#        > DELETE FROM pages WHERE id = 1;
#
#        > UPDATE pages SET title="A new title", content="Some new content" WHERE id=2

# %% [markdown]
# # Python中的SQL语句
#
#    1. 连接：
#
#       'localhost' 服务器端口号
#       conn = pymysql.connect(host(str),port(int),user(str), passwd(str),db(str),charset(str)(连接编码))
#
#    2. connection对象支持的方法：
#
#       cursor():游标 commit():提交当前事物 rollback():回滚当前事务 close()
#
#    3. cursor对象支持的方法:
#
#       execute(op)      执行一个数据库的查询命令
#
#       fetchone()       取得结果集的下一行:返回单个元组，即为一条记录，否则返回None
#
#       fetchmany(size)  获取结果集的下几行
#
#       fetchall()       获取结果集中的所有行:返回多个元组，即多个记录
#
#       rowcount()       返回数据条数或影响行数
#
#       close()          关闭游标对象
#
#    4. python mysql创建表
#
#       判断表是否存在
#
#          create table if not exists people(name,text,age,int(2),gender char(1));
#
#       例子：
#
#       Student = '''
#
#            create table Student(StdId int primary key not null,
#
#                         StdName varchar(100) not null,
#
#                         Gender enum('M','F') not null,
#
#                         Age int)
#
#                 '''
#
#       cur.execute(Student)
#
#    5. 插入操作
#
#       sql = """INSERT INTO Student(StdId,StdName,Gender,Age) VALUES(20181993,'wangruoyu','M',25)"""

# %%
import pymysql
conn = pymysql.connect(host='localhost',port=3306,user='root',passwd='25806')

cur = conn.cursor()
cur.execute("show databases")
#枚举出全部的数据库
print("The databases are :",cur.fetchall())

#创建一个数据库
database = '''
           create database if not exists School
           '''
cur.execute(database)

#使用School数据库
cur.execute("use School")

Student = '''
           create table if not exists Student(
               StdId int primary key not null,
               StdName varchar(100) not null,
               Gender enum('M','F') not null,
               Age int
            )
          '''
cur.execute(Student)

#插入操作
sql = """INSERT INTO Student(StdId,StdName,Gender,Age) 
         VALUES(20181993,'wangruoyu','M',25)"""

cur.execute(sql)
cur.execute("select * from Student")
print(cur.fetchall())
cur.close()
conn.close()
# Out:
# The databases are : (('information_schema',), ('eisti',), ('mysql',), ('performance_schema',), ('school',), ('sys',), ('test',))
# H:\anaconda\lib\site-packages\pymysql\cursors.py:165: Warning: (1007, "Can't create database 'school'; database exists")
#   result = self._query(query)
# ((20181993, 'wangruoyu', 'M', 25),)

# %%
import pymysql
conn = pymysql.connect(host='localhost',port=3306,user='root',passwd='25806')
cur  = conn.cursor()
cur.execute("show databases")
cur.execute("use eisti")

cur.execute("select * From open_medic")
show_data = cur.fetchall()
print(show_data)

cur.close()
conn.close()
# Out:
# (('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400930406267, '0', 0, 0, 1, 99, 99, 11, '7,52', '25,08', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 5, 1, 150, '116,67', '382,73', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 5, 12, 356, '276,99', '923,30', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 5, 90, 43, '33,27', '110,91', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 5, 98, 39, '30,01', '100,04', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 11, 1, 275, '164,38', '544,95', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 11, 12, 808, '482,94', '1.599,58', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 11, 90, 503, '308,29', '995,28', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 11, 98, 185, '109,82', '366,08', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 11, 99, 13, '7,66', '25,52', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 24, 1, 141, '89,30', '279,18', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 24, 12, 100, '59,34', '197,79', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 24, 90, 74, '45,34', '146,52', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 24, 98, 24, '14,26', '47,52', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 27, 1, 220, '130,98', '435,60', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 27, 12, 267, '158,72', '529,08', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 27, 90, 88, '53,66', '174,24', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 27, 98, 33, '19,54', '65,12', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 28, 1, 203, '120,52', '401,72', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 28, 12, 122, '72,34', '241,12', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 28, 90, 154, '92,80', '304,71', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 28, 98, 51, '31,68', '100,98', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 32, 1, 236, '140,05', '466,84', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 32, 12, 404, '239,98', '799,92', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 32, 90, 191, '117,02', '378,18', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 32, 98, 76, '45,08', '150,26', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 44, 1, 487, '302,63', '963,60', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 44, 12, 1650, '988,32', '3.265,02', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 44, 90, 478, '290,14', '946,00', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 44, 98, 113, '72,47', '223,74', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 44, 99, 12, '7,72', '23,76', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 52, 1, 97, '57,92', '192,06', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 52, 12, 283, '168,40', '560,34', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 52, 90, 50, '29,70', '99,00', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 52, 98, 22, '13,00', '43,34', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 53, 1, 65, '38,54', '128,48', 2014), ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 0, 1, 53, 12, 42, '24,95', ' ...

# %%
import pymysql

#创建一个连接
conn = pymysql.connect(host='localhost',port=3306,user='root',passwd='25806')

#创建一个游标
cur = conn.cursor()
cur.execute("show databases")


#转换到eisti这个数据库
cur.execute("USE eisti")
#执行一次选择
cur.execute("SELECT * FROM open_medic WHERE AGE BETWEEN 12 and 60")
#取得结果集的下一行
print(cur.fetchone())

cur.close()
conn.close()
# Out:
# ('A', 'A01', 'A01A', 'A01AA', 'A01AA01', 3400931911999, '0', 0, 20, 1, 11, 99, 26, '15,44', '51,48', 2014)

# %%
CREATE TABLE `users` (
    `id` int(11) NOT NULL AUTO_INCREMENT,
    `email` varchar(255) COLLATE utf8_bin NOT NULL,
    `password` varchar(255) COLLATE utf8_bin NOT NULL,
    PRIMARY KEY (`id`)
) ENGINE=InnoDB DEFAULT CHARSET=utf8 COLLATE=utf8_bin
AUTO_INCREMENT=1 ;
# Out:
#   File "<ipython-input-9-96607b4fc7b7>", line 1
#     CREATE TABLE `users` (
#                ^
# SyntaxError: invalid syntax

# %%
#创建数据库并且设置编码utf-8多语言
sql = "CREATE database 'test_2'DEFAULT CHARACTER SET utf8 collate utf8_general_ci"
#创建表
conn.execute(sql)
#选择这个新的数据库
conn.execute("use test_2")
#在该数据库中创建一个名为new_table的表
sql = """CREATE table article(Title VARCHAR(200),Author VARCHAR(20),Content VARCHAR(2000))"""
conn.execute(sql)

#插入操作
sql = """INSERT INTO article(Title,Author,Content)
         VALUES('wang!success','wang','I am wangruoyu,finally I am successful')""""
try:
    #执行sql
    cursor.execute(sql)
    #提交到数据库执行
    db.commit()
except:
    #如果发生错误
    db.rollback()
db.close()

# %%
#过滤重复记录 只显示一条记录
Select * From HZT Where ID in (Select Max(ID) From HZT Group by Title)
#查找全部重复记录
SELECT * FROM t_info a WHERE ((SELECT COUNT(*) FROM t_info WHERE Title = a.Title) > 1) ORDER BY Title DESC

# %%
import pymysql
connection = pymysql.connect(host='mysql-wang.cekkdnv29igt.us-west-2.rds.amazonaws.com',
                       port=3306,user='scrapy',passwd='scrapy25806',charset='utf8')
#cursor.execute("create table if not exists movie(name text, star text, quote text, info text)")
try:
    with connection.cursor() as cursor:
        #创建数据库并且设置编码utf-8多语言
        sql = "CREATE database if not exists test_2"
        cursor.execute(sql)  
        #选择这个新的数据库
        cursor.execute("use test_2")
        #在该数据库中创建一个名为new_table的表
        sql = "CREATE TABLE if not exists article(Title VARCHAR(200),Author VARCHAR(20),Content text)"
        cursor.execute(sql)
        sql = "INSERT INTO article(Title,Author,Content) VALUES(%s,%s,%s)"
        try:
            #执行sql
            cursor.execute(sql,('ruoyu!success','zhang','I am xiaoyue,finally I am successful'))
            #提交到数据库执行
            connection.commit()
        except:
            #如果发生错误
            connection.rollback()
        
finally:
    connection.close()

# %%
import pymysql
connection = pymysql.connect(host='mysql-wang.cekkdnv29igt.us-west-2.rds.amazonaws.com',
                       port=3306,user='scrapy',passwd='scrapy25806',charset='utf8')

#使用cursor()方法获取游标对象
try:
    with connection.cursor() as cursor:
        sql = "INSERT INTO `users` (`email`, `password`) VALUES (%s, %s)"
        cursor.execute(sql,('webmaster@python.org', 'very-secret'))
    connection.commit()
    with connection.cursor() as cursor:
        sql = "SELECT `id`, `password` FROM `users` WHERE `email`=%s"
        cursor.execute(sql, ('webmaster@python.org',))
        result = cursor.fetchone()
        print(result)
finally:
    connection.close()

# %%
# encoding:utf-8
'''
Created on 2018年5月1日

@author: liushouhua
'''

import requests
import json
import re
from bs4 import BeautifulSoup

url = "https://www.7234.cn/news/53774"
res = requests.get(url)
picture_pattern = re.compile('<p><img src="//(.*?)"><',re.S)
time_pattern = re.compile('</span><span>(.*?)</span>&nbsp',re.S)
content_pattern = re.compile('</script>.*?</div>(.*?)</p>',re.S)
if res.status_code == 200:
    contentlist = []
    data = res.content
#     print data
    time_item = re.findall(time_pattern,data)
    ll=time_item[0].split("<span>")
    time_item=ll[-1]
    
    print(time_item)
    picture_item = re.findall(picture_pattern,data)
#     content_item = re.findall(content_pattern,data)
#     print content_item
#     for item in content_item:
#         print item
#         contentlist.append(BeautifulSoup(item,'lxml').get_text())
#         print contentlist
    
    
    content=BeautifulSoup(data,'lxml').get_text()
#     print content

# %%
# encoding:utf-8
'''
作者：王若愚
功能：
     1.获取文章的页面链接
     2.保存文章内容
     3.保存文章图片
时间：2018/05/01
'''
from urllib.request import urlretrieve
import requests
import json
import re
import os
from bs4 import BeautifulSoup


class main(object):
    def __init__(self):
        self.baseurl = "https://www.7234.cn"        
        self.artset = set()#保存文章链接的集合除重
        #设置文件保存路径
        self.path = "H:\Desktop\scrapy"
    
    #设置爬取的起始页面号码
    def run(self,start_number=1,end_number=2):
        for i in range(start_number,end_number+1,1):
            post_data = {"page": i}#数字代表页数，通过改变数字爬取其他内容
            url = "https://www.7234.cn/fetch_articles/news?page=%s"%(post_data["page"])
            #开始抓取每一个页面中出现的文章链接
            self.get_article_link(url)
    
    def get_article_link(self,url):
        #获取页面内容
        res = requests.get(url)
        if res.status_code == 200:
            #将页面转化为json格式并获取html内容
            data = json.loads(res.content)
            html_json = data.get('html')
            #print(html_json)
            
            #获取文章后缀匹配任意字符
            artId = re.compile("href=(.*?) target")
            result1 = artId.findall(html_json)
            #匹配类似于/news/53805
            for i in result1:
                number = re.compile(r'/\w*/\d+')
                try:
                    Id = re.search(number,i).group()
                except AttributeError:
                    Id = None
                if Id != None:
                    artset.add(self.baseurl+Id)
            #保存文章链接
            artlist = list(i for i in artset)
            print(artlist)
            self.get_article_content(artlist) 
    def get_article_content(self,art):
        path = self.path
        #设定当前工作路径
        if not os.path.exists(path):
            os.mkdir(path)
        
        for art in artlist:
            print("the link is:",art)
            article_html = requests.get(art)
            bs0bj = BeautifulSoup(article_html.text,'lxml')
            #获取文章的标题
            try:
                title = bs0bj.find('div',class_="article-inner").find("h1").get_text()
            except:
                title = "The article is None"
            #设定文章所在文件夹的名字
            path = path+"\\"+title
            #创建文章文件夹用以保存文章内容的txt文件和图片
            if not os.path.exists(path):
                os.mkdir(path)
                
            #文章内容链表
            para_content = []
            #文章图片链表
            photo_link = []

            #获取文章的内容
            content = bs0bj.find("div",{"class":"a-content"})
            try:
                paragraph = content.find_all("p")
                #分别对每个自然段进行分析
                for p in paragraph:
                    #获取文章中的图片
                    para_content.append(p.get_text())
                    try:
                        ph = "https:"+p.find("img")["src"]
                    except:
                        ph = None
                    if ph != None:
                        photo_link.append(ph)
            except:
                paragraph = "The content is none"

            print("The title is:",title)
            print("The content is:",para_content)
            try:
                f = open(path+"\\"+title+".txt","w+",encoding='utf8')
                for i in para_content:
                    f.write(i+'\n')
            except:
                print("The file is not open")
            print("The link is:",photo_link)
            for i in range(len(photo_link)):
                urlretrieve (photo_link[i], path+"\\"+str(i)+".jpg")
            f.close()
            path = self.path



if __name__ == "__main__":
    title = main()
try:    
    title.run(1)
except ConnectionError as e:
    print(e)

# %%
from bs4 import BeautifulSoup
art = artlist[0]
article_html = requests.get(art)
bs0bj = BeautifulSoup(article_html.text,'lxml')

title = bs0bj.find('div',class_="article-inner").find("h1").get_text()
print("The title is:",title)
paragraph = bs0bj.find("div",{"class":"a-content"}).find_all("p")
for p in paragraph:
    print("The content is:",p.get_text())

# %%
import os
path = "H:\Desktop\wang"
if os.path.isdir(path):
    print("exit")
else:
    os.mkdir(path)

# %%
from bs4 import BeautifulSoup
import os
import requests
from urllib.request import urlretrieve
import json
import re

#设定当前工作目录
path = "H:\Desktop\scrapy"
if not os.path.exists(path):
    os.mkdir(path)

art = "https://www.7234.cn/news/53905"
print("the link is:",art)
article_html = requests.get(art)
bs0bj = BeautifulSoup(article_html.text,'lxml')

#获取文章的标题
try:
    title = bs0bj.find('div',class_="article-inner").find("h1").get_text()
except:
    title = "The article is None"
path = "H:\Desktop\scrapy"+"\\"+title
if not os.path.exists(path):
    os.mkdir(path)

#文章内容链表
para_content = []
#文章图片链表
photo_link = []

#获取文章的内容
content = bs0bj.find("div",{"class":"a-content"})
try:
    paragraph = content.find_all("p")
    for p in paragraph:
        #获取文章中的图片
        para_content.append(p.get_text())
        try:
            ph = "https:"+p.find("img")["src"]
        except:
            ph = None
        if ph != None:
            photo_link.append(ph)
except:
    paragraph = "The content is none"

print("The title is:",title)
print("The content is:",para_content)
try:
    f = open(path+"\\"+title+".txt","w+",encoding='utf8')
    for i in para_content:
        f.write(i+'\n')
except:
    print("The file is not open")
print("The link is:",photo_link)
for i in range(len(photo_link)):
    urlretrieve(photo_link[i], path+"\\"+str(i)+".jpg")
f.close()

# %%
print(content)

# %%
string = "Xiaoyue,loves,ruoyu"
strings = string.split(",")
print(strings)
print("Xiaoyu"+"\n"+"loves"+"\n"+"ruoyu")

# %%
article = content.split("</")
print(article)

# %%
test = content.get_text().split("\n")
for i in range(len(test)):
    print(i)
    print(test[i])

# %%
print(paragraph)

# %%
from urllib.request import urlretrieve
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://www.pythonscraping.com")
bsObj = BeautifulSoup(html)
imageLocation = bsObj.find("a", {"id": "logo"}).find("img")["src"]
urlretrieve (imageLocation, "H:/Desktop/logo.jpg")

# %%
import requests
import re
from bs4 import BeautifulSoup
import json

url = "https://www.ihuoqiu.com/MAPI/GetArticleInfoData"
url_data = "x8s4uNphJVUkxLR7EjGwBw__2C__2C"
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36",
    "Connection":"keep-alive",
    "Content-Type":"application/json;charset=UTF-8",
    "Origin":"http://m.ihuoqiu.com",
    "Referer":"http://m.ihuoqiu.com/article?id=x8s4uNphJVUkxLR7EjGwBw__2C__2C&type=1"
}
data = '''{Type: "1", data: "%s"}'''%url_data
response =requests.post(url=url,data=data,headers=headers)

if response.status_code == 200:
    article_json = json.loads(response.content)
    article_content = article_json.get("data",[])
    art_content_list = article_content.split(',"')
    article = art_content_list[2].split("。<")
    article1 = []
    
    for i in article:
        article1.append(BeautifulSoup(i,'lxml').get_text())
    
    for j in article1:
        print(j)
